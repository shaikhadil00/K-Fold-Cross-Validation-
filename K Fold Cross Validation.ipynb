# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_diabetes
import matplotlib.pyplot as plt

# %%
# Load the Diabetes dataset
data = load_diabetes()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target)

# %%
# Initialize the model
model = LinearRegression()

# %%
# Number of folds
k = 5

# %%
# Initialize K-Fold
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# %%
# Perform K-Fold Cross Validation
scores = cross_val_score(model, X, y, cv=kf, scoring='r2')

# %%
# Print the results
print(f"R2 Scores for each fold: {scores}")
print(f"Mean R2 Score: {np.mean(scores)}")
print(f"Standard Deviation of R2 Scores: {np.std(scores)}")
# Out:
# R2 Scores for each fold: [0.45260276 0.57320015 0.39144785 0.58428888 0.39081186]
# Mean R2 Score: 0.47847030225778475
# Standard Deviation of R2 Scores: 0.0849674692576176

# %%
# Plotting the R2 scores for each fold
plt.figure(figsize=(10, 6))
plt.plot(range(1, k+1), scores, marker='o', linestyle='--', color='b')
plt.title(f'{k}-Fold Cross Validation R2 Scores')
plt.xlabel('Fold')
plt.ylabel('R2 Score')
plt.ylim(0, 1)
plt.grid(True)
plt.show()

# %% [markdown]
# # Explanation

# %%
Imports: Necessary libraries including numpy, pandas, scikit-learn, and matplotlib.

Load Dataset: Load the Diabetes dataset from scikit-learn.

Initialize Model: Initialize a linear regression model.

# %% [markdown]
# # K-Fold Cross Validation

# %%
Set the number of folds (k = 5).

Initialize the K-Fold cross-validator with 5 splits, shuffling the data and setting a random seed.

Perform K-Fold cross-validation using the cross_val_score function, which returns the R2 scores for each fold.

Print Results: Print the R2 scores for each fold, the mean R2 score, and the standard deviation of the R2 scores.

Plotting: Plot the R2 scores for each fold to visualize the performance.
